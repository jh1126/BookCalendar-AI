# %% [markdown]
# <a href="https://colab.research.google.com/github/jh1126/BookCalendar-AI/blob/main/%EC%B1%97%EB%B4%87_%EB%8D%B0%EC%9D%B4%ED%84%B0%EC%85%8B_%EC%A0%84%EC%B2%98%EB%A6%AC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded1 = files.upload()
# Out:
#      <input type="file" id="files-161a4adc-ac5e-43ac-99bc-8ac0c439f467" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-161a4adc-ac5e-43ac-99bc-8ac0c439f467">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

# 업로드한 파일 이름을 사용하여 데이터프레임으로 변환
file_name1 = list(uploaded1.keys())[0]  # 업로드한 첫 번째 파일 이름을 사용
data1 = pd.read_csv(file_name1, encoding='cp949')

#출력
data1.head()
# Out:
#                                  text  intent
# 0                 반갑습니다 어떤 안내가 필요하신가요       1
# 1  해외에서 귀국하는 학생인데 전입에 필요한 서류가 어떻게 되나요       1
# 2                  서류 준비 후 어디로 가면 되나요       1
# 3                   다른 안내 필요한 거 없으신가요       1
# 4                         네 어떤 문의이실까요       1

# %%
len(data1)
# Out:
# 147008

# %%
data1.loc[(data1['intent'] == 1), 'intent'] = '질문'

# %%
data1.head()
# Out:
#                                  text intent
# 0                 반갑습니다 어떤 안내가 필요하신가요     질문
# 1  해외에서 귀국하는 학생인데 전입에 필요한 서류가 어떻게 되나요     질문
# 2                  서류 준비 후 어디로 가면 되나요     질문
# 3                   다른 안내 필요한 거 없으신가요     질문
# 4                         네 어떤 문의이실까요     질문

# %%
from google.colab import files
uploaded2 = files.upload()
# Out:
#      <input type="file" id="files-ac5ca2d6-b868-4b5d-9878-0034f1d7c658" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ac5ca2d6-b868-4b5d-9878-0034f1d7c658">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# 업로드한 파일 이름을 사용하여 데이터프레임으로 변환
file_name2 = list(uploaded2.keys())[0]  # 업로드한 첫 번째 파일 이름을 사용
data2 = pd.read_csv(file_name2, encoding='cp949')

#출력
data2.head()
# Out:
#                      text  intent
# 0              아 네 말씀해주세요       1
# 1  평화누리길 두 코스가 대략 어떻게 되나요       1
# 2           산길이 가파르지는 않나요       1
# 3       네 고객님 편하게 말씀해 주세요       1
# 4     클라이밍 운영 시간이 어떻게 되나요       1

# %%
len(data2)
# Out:
# 16770

# %%
data2.loc[(data2['intent'] == 1), 'intent'] = '질문'
# Out:
# <ipython-input-14-f593fc4b5adf>:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '질문' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data2.loc[(data2['intent'] == 1), 'intent'] = '질문'

# %%
data2.head()
# Out:
#                      text intent
# 0              아 네 말씀해주세요     질문
# 1  평화누리길 두 코스가 대략 어떻게 되나요     질문
# 2           산길이 가파르지는 않나요     질문
# 3       네 고객님 편하게 말씀해 주세요     질문
# 4     클라이밍 운영 시간이 어떻게 되나요     질문

# %%
question = pd.concat([data1, data2], ignore_index=True)

# %%
question.head()
# Out:
#                                  text intent
# 0                 반갑습니다 어떤 안내가 필요하신가요     질문
# 1  해외에서 귀국하는 학생인데 전입에 필요한 서류가 어떻게 되나요     질문
# 2                  서류 준비 후 어디로 가면 되나요     질문
# 3                   다른 안내 필요한 거 없으신가요     질문
# 4                         네 어떤 문의이실까요     질문

# %%
len(question)
# Out:
# 163778

# %%
from google.colab import files
uploaded3 = files.upload()
# Out:
#      <input type="file" id="files-a0e5f44f-4647-49bb-9006-346dca9b1998" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a0e5f44f-4647-49bb-9006-346dca9b1998">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# 업로드한 파일 이름을 사용하여 데이터프레임으로 변환
file_name3 = list(uploaded3.keys())[0]  # 업로드한 첫 번째 파일 이름을 사용
data3 = pd.read_excel(file_name3)

#출력
data3.head()
# Out:
#                                text  intent
# 0          요리 장르를 읽고 싶은데 책 좀 추천해줄래?       0
# 1                 과학 책 추천 받을 수 있을까?       0
# 2                   경제 관련 책 뭐가 재밌어?       0
# 3                        코믹 책 뭐 읽지?       0
# 4  모든 관계는 말투에서 시작된다이랑 비슷한 도서 뭐 있을까?       0

# %%
data3.loc[(data3['intent'] == 0), 'intent'] = '추천'
# Out:
# <ipython-input-21-8ab272633789>:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '추천' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data3.loc[(data3['intent'] == 0), 'intent'] = '추천'

# %%
len(data3)
# Out:
# 269281

# %%
data3.head()
# Out:
#                                text intent
# 0          요리 장르를 읽고 싶은데 책 좀 추천해줄래?     추천
# 1                 과학 책 추천 받을 수 있을까?     추천
# 2                   경제 관련 책 뭐가 재밌어?     추천
# 3                        코믹 책 뭐 읽지?     추천
# 4  모든 관계는 말투에서 시작된다이랑 비슷한 도서 뭐 있을까?     추천

# %%
from google.colab import files
uploaded4 = files.upload()
# Out:
#      <input type="file" id="files-d4b664d9-617d-439d-b4fd-35c06dca6698" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d4b664d9-617d-439d-b4fd-35c06dca6698">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# 업로드한 파일 이름을 사용하여 데이터프레임으로 변환
file_name4 = list(uploaded4.keys())[0]  # 업로드한 첫 번째 파일 이름을 사용
data4 = pd.read_excel(file_name4)

#출력
data4.head()
# Out:
#                                       text  intent
# 0                         에세이 관련 책 뭐가 재밌어?       0
# 1                고전 역사 책 중에서 추천해줄 만한 거 있어?       0
# 2             책의 정신을 즐겁게 읽었는데 비슷한 책 또 있을까?       0
# 3  달러구트 꿈 백화점을 재미있게 읽었는데 비슷한 책 추천 받을 수 있어?       0
# 4                   데미안 읽고 난 후 읽을만한 책 있을까?       0

# %%
data4.loc[(data4['intent'] == 0), 'intent'] = '추천'
# Out:
# <ipython-input-25-bd08ce51db91>:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '추천' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data4.loc[(data4['intent'] == 0), 'intent'] = '추천'

# %%
len(data4)
# Out:
# 30719

# %%
data4.head()
# Out:
#                                       text intent
# 0                         에세이 관련 책 뭐가 재밌어?     추천
# 1                고전 역사 책 중에서 추천해줄 만한 거 있어?     추천
# 2             책의 정신을 즐겁게 읽었는데 비슷한 책 또 있을까?     추천
# 3  달러구트 꿈 백화점을 재미있게 읽었는데 비슷한 책 추천 받을 수 있어?     추천
# 4                   데미안 읽고 난 후 읽을만한 책 있을까?     추천

# %%
recom = pd.concat([data3, data4], ignore_index=True)

# %%
len(recom)
# Out:
# 300000

# %%
smple = data1.sample(n=14000, random_state=42)

# %%
question = pd.concat([smple, data2], ignore_index=True)

# %%
len(question)
# Out:
# 30770

# %%
train_df = pd.concat([question, data4], ignore_index=True)

# %%
len(train_df)
# Out:
# 61489

# %%
# 값의 개수 세기
value_counts = train_df['intent'].value_counts()

# 막대그래프 그리기 (matplotlib 사용)
value_counts.plot(kind='bar')
plt.title('Category Distribution')
plt.xlabel('Category')
plt.ylabel('Count')
plt.show()

# 또는 seaborn 사용
sns.countplot(x='Category', data=df)
plt.title('Category Distribution')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-cbaf8515f29b> in <cell line: 0>()
#       4 # 막대그래프 그리기 (matplotlib 사용)
#       5 value_counts.plot(kind='bar')
# ----> 6 plt.title('Category Distribution')
#       7 plt.xlabel('Category')
#       8 plt.ylabel('Count')
#
# NameError: name 'plt' is not defined
# /usr/local/lib/python3.11/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 51656 (\N{HANGUL SYLLABLE JIL}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 47928 (\N{HANGUL SYLLABLE MUN}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 52628 (\N{HANGUL SYLLABLE CU}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# ...

# %%
# 엑셀로 저장 (기본 시트 이름: 'Sheet1')
train_df.to_excel('질문의도분류 데이터셋61489.xlsx', index=False)
files.download('질문의도분류 데이터셋61489.xlsx')

# %%
train_df.head()
# Out:
#                       text intent
# 0         예 전번 맞는지 확인해 주세요     질문
# 1    어플리케이션 납부는 뭐를 깔아야 할까요     질문
# 2  저 해외 거주자인데요 회원가입이 가능할까요     질문
# 3       그럼 아이들이 마실 음료도 있나요     질문
# 4      반갑습니다 어떤 안내가 필요하신가요     질문
