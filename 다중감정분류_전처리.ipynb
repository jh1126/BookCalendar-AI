# %% [markdown]
# <a href="https://colab.research.google.com/github/jh1126/BookCalendar-AI/blob/main/%EB%8B%A4%EC%A4%91%EA%B0%90%EC%A0%95%EB%B6%84%EB%A5%98_%EC%A0%84%EC%B2%98%EB%A6%AC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-d80c74bc-2179-4c8f-b7ef-96c3eb4d388a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d80c74bc-2179-4c8f-b7ef-96c3eb4d388a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

# 업로드한 파일 이름을 사용하여 데이터프레임으로 변환
file_name = list(uploaded.keys())[0]  # 업로드한 첫 번째 파일 이름을 사용
train_df = pd.read_excel(file_name)

#출력
train_df.head()
# Out:
#   감정_대분류                                              사람문장1
# 0     분노                          일은 왜 해도 해도 끝이 없을까? 화가 난다.
# 1     분노     이번 달에 또 급여가 깎였어! 물가는 오르는데 월급만 자꾸 깎이니까 너무 화가 나.
# 2     분노  회사에 신입이 들어왔는데 말투가 거슬려. 그런 애를 매일 봐야 한다고 생각하니까 스...
# 3     분노  직장에서 막내라는 이유로 나에게만 온갖 심부름을 시켜. 일도 많은 데 정말 분하고 ...
# 4     분노              얼마 전 입사한 신입사원이 나를 무시하는 것 같아서 너무 화가 나.

# %%
#7개의 감정을 숫자로 표현
# 7개의 감정 class → 숫자
train_df.loc[(train_df['감정_대분류'] == 0), '감정_대분류'] = '분노' # 분노 → 0
train_df.loc[(train_df['감정_대분류'] == 1), '감정_대분류'] = '기쁨'  # 기쁨 → 1
train_df.loc[(train_df['감정_대분류'] == 2), '감정_대분류'] = '불안'  # 불안 → 2
train_df.loc[(train_df['감정_대분류'] == 3), '감정_대분류'] = '당황'   #당황 → 3
train_df.loc[(train_df['감정_대분류'] == 4), '감정_대분류'] = '슬픔' # 슬픔 → 4
# Out:
# <ipython-input-5-846a94aee5b3>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '분노' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df.loc[(train_df['감정_대분류'] == 0), '감정_대분류'] = '분노' # 분노 → 0

# %%
train_df.head()
# Out:
#   감정_대분류                                              사람문장1
# 0     분노                          일은 왜 해도 해도 끝이 없을까? 화가 난다.
# 1     분노     이번 달에 또 급여가 깎였어! 물가는 오르는데 월급만 자꾸 깎이니까 너무 화가 나.
# 2     분노  회사에 신입이 들어왔는데 말투가 거슬려. 그런 애를 매일 봐야 한다고 생각하니까 스...
# 3     분노  직장에서 막내라는 이유로 나에게만 온갖 심부름을 시켜. 일도 많은 데 정말 분하고 ...
# 4     분노              얼마 전 입사한 신입사원이 나를 무시하는 것 같아서 너무 화가 나.

# %%
import numpy as np
import pandas as pd

# 값의 개수 세기
value_counts = train_df['감정_대분류'].value_counts()

# 막대그래프 그리기 (matplotlib 사용)
value_counts.plot(kind='bar')
plt.title('Category Distribution')
plt.xlabel('Category')
plt.ylabel('Count')
plt.show()

# 또는 seaborn 사용
sns.countplot(x='Category', data=df)
plt.title('Category Distribution')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-885b12d54f94> in <cell line: 0>()
#       7 # 막대그래프 그리기 (matplotlib 사용)
#       8 value_counts.plot(kind='bar')
# ----> 9 plt.title('Category Distribution')
#      10 plt.xlabel('Category')
#      11 plt.ylabel('Count')
#
# NameError: name 'plt' is not defined
# /usr/local/lib/python3.11/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 49836 (\N{HANGUL SYLLABLE SEUL}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 54548 (\N{HANGUL SYLLABLE PEUM}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 48516 (\N{HANGUL SYLLABLE BUN}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# ...

# %%
import numpy as np
import pandas as pd

# 1. 'B' 열에서 'apple' 값인 행을 필터링
apple_rows = train_df[train_df['감정_대분류'] == '슬픔']

# 2. 삭제할 행의 개수를 지정 (예: 랜덤으로 2개의 'apple' 행 삭제)
num_to_delete = 10000

# 3. 랜덤하게 삭제할 인덱스를 선택
random_indices = np.random.choice(apple_rows.index, num_to_delete, replace=False)

# 4. 해당 행들을 삭제
df_dropped = train_df.drop(random_indices)

# %%
# 1. 'B' 열에서 'apple' 값인 행을 필터링
apple_rows = df_dropped[df_dropped['감정_대분류'] == '분노']

# 2. 삭제할 행의 개수를 지정 (예: 랜덤으로 2개의 'apple' 행 삭제)
num_to_delete = 7000

# 3. 랜덤하게 삭제할 인덱스를 선택
random_indices = np.random.choice(apple_rows.index, num_to_delete, replace=False)

# 4. 해당 행들을 삭제
df_dropped1 = df_dropped.drop(random_indices)

# %%
value_counts = df_dropped1['감정_대분류'].value_counts()

print(value_counts)
# Out:
# 감정_대분류
# 분노    22955
# 불안    22771
# 슬픔    22268
# 당황    19267
# 기쁨    16800
# Name: count, dtype: int64

# %%
# 1. 특정 값을 가지는 행 선택 (예: label이 'A'인 행)
target_class = '기쁨'
target_rows = df_dropped1[df_dropped1['감정_대분류'] == target_class]

# 2. 오버샘플링 (예: 5000개로 늘리기)
oversampled = target_rows.sample(n=5000, replace=True, random_state=42)

# 3. 기존 데이터프레임과 합치기
df_oversampled = pd.concat([df_dropped1, oversampled], ignore_index=True)

# 결과 확인
print(df_oversampled['감정_대분류'].value_counts())
# Out:
# 감정_대분류
# 분노    22955
# 불안    22771
# 슬픔    22268
# 기쁨    21800
# 당황    19267
# Name: count, dtype: int64

# %%
len(df_oversampled)
# Out:
# 109061

# %%
# 엑셀로 저장 (기본 시트 이름: 'Sheet1')
df_oversampled.to_excel('감정분류데이터셋109061_샘플링.xlsx', index=False)
files.download('감정분류데이터셋109061_샘플링.xlsx')

# %%
# 값의 개수 세기
value_counts = df_dropped['감정_대분류'].value_counts()

# 막대그래프 그리기 (matplotlib 사용)
value_counts.plot(kind='bar')
plt.title('Category Distribution')
plt.xlabel('Category')
plt.ylabel('Count')
plt.show()

# 또는 seaborn 사용
sns.countplot(x='Category', data=df)
plt.title('Category Distribution')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-0c457b87114f> in <cell line: 0>()
#       4 # 막대그래프 그리기 (matplotlib 사용)
#       5 value_counts.plot(kind='bar')
# ----> 6 plt.title('Category Distribution')
#       7 plt.xlabel('Category')
#       8 plt.ylabel('Count')
#
# NameError: name 'plt' is not defined
# /usr/local/lib/python3.11/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 48516 (\N{HANGUL SYLLABLE BUN}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 45432 (\N{HANGUL SYLLABLE NO}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 48520 (\N{HANGUL SYLLABLE BUL}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# ...

# %%
train_df['감정_대분류'].unique()
# Out:
# array(['분노', '기쁨', '불안', '당황', '슬픔'], dtype=object)

# %%
import pandas as pd

# 업로드한 파일 이름을 사용하여 데이터프레임으로 변환
file_name2 = list(uploaded2.keys())[0]  # 업로드한 첫 번째 파일 이름을 사용
train_df2 = pd.read_csv(file_name2, encoding='cp949')

# 필요한 열만 남김
columns_to_keep = ['발화문','상황']
train_df2 = train_df2[columns_to_keep]

#출력
train_df2.head()
# Out:
#                          발화문     상황
# 0           어, 청소 니가 대신 해 줘!  anger
# 1         둘 다 청소 하기 싫어. 귀찮아.  anger
# 2             둘 다 하기 싫어서 화내.  anger
# 3                그럼 방세는 어떡해.  anger
# 4  권태긴줄 알았는데 다른 사람이 생겼나보더라고.    sad

# %%
train_df2=train_df2[['상황','발화문']]

# %%
train_df2['상황'].unique()
# Out:
# array(['anger', 'sad', 'fear', 'disgust', 'neutral'], dtype=object)

# %%
train_df2 = train_df2[train_df2['상황'] != 'disgust']

# %%
#7개의 감정을 숫자로 표현
# 7개의 감정 class → 숫자
train_df2.loc[(train_df2['상황'] == "anger"), '상황'] = 0  # 분노 → 0
train_df2.loc[(train_df2['상황'] == "기쁨"), '상황'] = 1  # 기쁨 → 1
train_df2.loc[(train_df2['상황'] == "fear"), '상황'] = 2  # 불안 → 2
train_df2.loc[(train_df2['상황'] == "당황"), '상황'] = 3  # 당황 → 3
train_df2.loc[(train_df2['상황'] == "sad"), '상황'] = 4  # 슬픔 → 4
train_df2.loc[(train_df2['상황'] == "상처"), '상황'] = 5  # 상처 → 5
train_df2.loc[(train_df2['상황'] == "neutral"), '상황'] = 6  # 중립 → 6

# %%
train_df2_renamed = train_df2.rename(columns={
    '상황': '감정_대분류',
    '발화문': '사람문장1'
})

train_df2 = train_df2_renamed[['감정_대분류', '사람문장1']]

# %%
train_df2['감정_대분류'].unique()
# Out:
# array([0, 4, 2, 6], dtype=object)

# %%
train_df = pd.concat([train_df, train_df2], ignore_index=True)

# %%
len(train_df)
# Out:
# 73908

# %%
# 파일 업로드
uploaded3 = files.upload()
# Out:
#      <input type="file" id="files-f3082ef9-8238-4560-849b-762523da65c5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f3082ef9-8238-4560-849b-762523da65c5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

# 업로드한 파일 이름을 사용하여 데이터프레임으로 변환
file_name3 = list(uploaded3.keys())[0]  # 업로드한 첫 번째 파일 이름을 사용
train_df3 = pd.read_csv(file_name3, encoding='cp949')

# 필요한 열만 남김
columns_to_keep = ['발화문','상황']
train_df3 = train_df3[columns_to_keep]

#출력
train_df3.head()
# Out:
#                                                  발화문         상황
# 0                                   헐! 나 이벤트에 당첨 됐어.  happiness
# 1        내가 좋아하는 인플루언서가 이벤트를 하더라고. 그래서 그냥 신청 한번 해봤지.  happiness
# 2                        한 명 뽑는 거였는데, 그게 바로 내가 된 거야.  happiness
# 3  당연히 마음에 드는 선물이니깐, 이벤트에 내가 신청 한번 해본 거지. 비싼 거야. ...  happiness
# 4                   에피타이저 정말 좋아해. 그 것도 괜찮은 생각인 것 같애.    neutral

# %%
train_df3=train_df3[['상황','발화문']]

# %%
train_df3['상황'].unique()
# Out:
# array(['happiness', 'neutral', 'sadness', 'angry', 'surprise', 'disgust',
#        'fear'], dtype=object)

# %%
train_df3 = train_df3[train_df3['상황'] != 'disgust']

# %%
#7개의 감정을 숫자로 표현
# 7개의 감정 class → 숫자
train_df3.loc[(train_df3['상황'] == "angry"), '상황'] = 0  # 분노 → 0
train_df3.loc[(train_df3['상황'] == "happiness"), '상황'] = 1  # 기쁨 → 1
train_df3.loc[(train_df3['상황'] == "fear"), '상황'] = 2  # 불안 → 2
train_df3.loc[(train_df3['상황'] == "surprise"), '상황'] = 3  # 당황 → 3
train_df3.loc[(train_df3['상황'] == "sad"), '상황'] = 4  # 슬픔 → 4
train_df3.loc[(train_df3['상황'] == "sadness"), '상황'] = 4  # 슬픔 → 4
train_df3.loc[(train_df3['상황'] == "hurt"), '상황'] = 5  # 상처 → 5
train_df3.loc[(train_df3['상황'] == "neutral"), '상황'] = 6  # 중립 → 6

# %%
train_df3_renamed = train_df3.rename(columns={
    '상황': '감정_대분류',
    '발화문': '사람문장1'
})

train_df3 = train_df3_renamed[['감정_대분류', '사람문장1']]

# %%
train_df3['감정_대분류'].unique()
# Out:
# array([1, 6, 4, 0, 3, 2], dtype=object)

# %%
train_df = pd.concat([train_df, train_df3], ignore_index=True)

# %%
len(train_df)
# Out:
# 90961

# %%
# 엑셀로 저장 (기본 시트 이름: 'Sheet1')
train_df.to_excel('감정분류학습데이터90961.xlsx', index=False)
files.download('감정분류학습데이터90961.xlsx')
